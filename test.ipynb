# %%
import pandas as pd

# %% [markdown]
# Using id

# %%
df = pd.read_csv('csv/CreditCardId.csv')

df
# Out:
#                                             Question  \
# 0  What are the credit card informations of the u...
# 1  What are the credit card informations of the u...
# 2  What are the credit card informations of the u...
# 3  What are the credit card informations of the u...
# 4  What are the credit card informations of the u...
#
#                                               Answer  \
# 0  the credit card with the id of 1 is a Superior...
# 1  the credit card with the id of 2 is a Distingu...
# 2  the credit card with the id of 3 is a Colonial...
# 3  the credit card with the id of 4 is a Colonial...
# 4  the credit card with the id of 5 is a Vista wi...
#
#                                          SQL Query
# 0  SELECT * FROM CreditCard WHERE CreditCardID = 1
# 1  SELECT * FROM CreditCard WHERE CreditCardID = 2
# 2  SELECT * FROM CreditCard WHERE CreditCardID = 3
# 3  SELECT * FROM CreditCard WHERE CreditCardID = 4
# 4  SELECT * FROM CreditCard WHERE CreditCardID = 5

# %% [markdown]
# Using credit card number

# %%
df = pd.read_csv('csv/CreditCardId.csv')
df.head()
# Out:
#                                             Question  \
# 0  What are the credit card informations of the u...
# 1  What are the credit card informations of the u...
# 2  What are the credit card informations of the u...
# 3  What are the credit card informations of the u...
# 4  What are the credit card informations of the u...
#
#                                               Answer  \
# 0  the credit card with the id of 1 is a Superior...
# 1  the credit card with the id of 2 is a Distingu...
# 2  the credit card with the id of 3 is a Colonial...
# 3  the credit card with the id of 4 is a Colonial...
# 4  the credit card with the id of 5 is a Vista wi...
#
#                                          SQL Query
# 0  SELECT * FROM CreditCard WHERE CreditCardID = 1
# 1  SELECT * FROM CreditCard WHERE CreditCardID = 2
# 2  SELECT * FROM CreditCard WHERE CreditCardID = 3
# 3  SELECT * FROM CreditCard WHERE CreditCardID = 4
# 4  SELECT * FROM CreditCard WHERE CreditCardID = 5

# %% [markdown]
# Using Exp date

# %%
df = pd.read_csv('csv/CreditCardExpirationDate.csv')

df.head()
# Out:
#                                             Question  \
# 0  What are the credit card informations of the u...
# 1  What are the credit card informations of the u...
# 2  What are the credit card informations of the u...
# 3  What are the credit card informations of the u...
# 4  What are the credit card informations of the u...
#
#                                               Answer  \
# 0  the credit card with the expiration date of 11...
# 1  the credit card with the expiration date of 8/...
# 2  the credit card with the expiration date of 7/...
# 3  the credit card with the expiration date of 7/...
# 4  the credit card with the expiration date of 4/...
#
#                                            SQL Query
# 0  SELECT * FROM CreditCard WHERE ExpirationDate ...
# 1  SELECT * FROM CreditCard WHERE ExpirationDate ...
# 2  SELECT * FROM CreditCard WHERE ExpirationDate ...
# 3  SELECT * FROM CreditCard WHERE ExpirationDate ...
# 4  SELECT * FROM CreditCard WHERE ExpirationDate ...

# %% [markdown]
# USing last modified date

# %%
df = pd.read_csv('csv/CreditCardLastModificationDate.csv')

df.head()
# Out:
#                                             Question  \
# 0  What are the credit card informations of the u...
# 1  What are the credit card informations of the u...
# 2  What are the credit card informations of the u...
# 3  What are the credit card informations of the u...
# 4  What are the credit card informations of the u...
#
#                                               Answer  \
# 0  the credit card with the last modification dat...
# 1  the credit card with the last modification dat...
# 2  the credit card with the last modification dat...
# 3  the credit card with the last modification dat...
# 4  the credit card with the last modification dat...
#
#                                            SQL Query
# 0  SELECT * FROM CreditCard WHERE LastModificatio...
# 1  SELECT * FROM CreditCard WHERE LastModificatio...
# 2  SELECT * FROM CreditCard WHERE LastModificatio...
# 3  SELECT * FROM CreditCard WHERE LastModificatio...
# 4  SELECT * FROM CreditCard WHERE LastModificatio...
